# %%
# !pip install matplotlib
# !pip install numpy
# !pip install seaborn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.6/157.6 kB 778.3 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 7.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.4/313.4 kB 8.1 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 6.8 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 5.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 6.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 1.0 MB/s eta 0:00:00a 0:00:01m
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("pokemon.csv")

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df['Type 1'].value_counts().plot(kind='pie', autopct='%1.1f%%', cmap='tab20c', figsize=(10,7))
# Out:
# <Axes: ylabel='count'>

# %%
df['Total'].plot(kind='hist', figsize=(10,8))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Total'].max()
# Out:
# 780

# %%
df['Total'].plot(kind='box', vert=False, figsize=(10,8))
# Out:
# <Axes: >

# %%
df['Total'].describe()
# Out:
# count    800.00000
# mean     435.10250
# std      119.96304
# min      180.00000
# 25%      330.00000
# 50%      450.00000
# 75%      515.00000
# max      780.00000
# Name: Total, dtype: float64

# %%
df['Legendary'].value_counts().plot(kind='pie', autopct='%1.1f%%', cmap='Set3', figsize=(10,7))
# Out:
# <Axes: ylabel='count'>

# %%
sns.boxplot(data = df, x='Attack')
# Out:
# <Axes: xlabel='Attack'>

# %%
df['Attack'].max()
# Out:
# 190

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.loc[df['Attack'] >= 190]
# Out:
#        #                 Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 163  150  MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      154      100    130           1       True

# %%
df.query('Attack >188')
# Out:
#        #                 Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 163  150  MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      154      100    130           1       True

# %%
sns.boxplot(data=df, x = 'Speed')
# Out:
# <Axes: xlabel='Speed'>

# %%
 df.query('Speed<=10')
# Out:
#        #       Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 230  213    Shuckle     Bug   Rock    505   20      10      230       10
# 359  328   Trapinch  Ground    NaN    290   45     100       45       45
# 486  438     Bonsly    Rock    NaN    290   50      80       95       10
# 495  446   Munchlax  Normal    NaN    390  135      85       40       40
# 658  597  Ferroseed   Grass  Steel    305   44      50       91       24
#
#      Sp. Def  Speed  Generation  Legendary
# 230      230      5           2      False
# 359       45     10           3      False
# 486       45     10           4      False
# 495       85      5           4      False
# 658       86     10           5      False

# %%
df.loc[df['Speed']<=10]
# Out:
#        #       Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 230  213    Shuckle     Bug   Rock    505   20      10      230       10
# 359  328   Trapinch  Ground    NaN    290   45     100       45       45
# 486  438     Bonsly    Rock    NaN    290   50      80       95       10
# 495  446   Munchlax  Normal    NaN    390  135      85       40       40
# 658  597  Ferroseed   Grass  Steel    305   44      50       91       24
#
#      Sp. Def  Speed  Generation  Legendary
# 230      230      5           2      False
# 359       45     10           3      False
# 486       45     10           4      False
# 495       85      5           4      False
# 658       86     10           5      False

# %%
(df['Speed'] <= 10).sum()
# Out:
# 5

# %%
(df['Sp. Def'] <= 25).sum()
# Out:
# 18

# %%
#(df['Sp. Def'] <= 25).sum()
df.loc[df['Sp. Def']<=25]
# Out:
#        #                Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 13    10            Caterpie      Bug     NaN    195   45      30       35
# 14    11             Metapod      Bug     NaN    205   50      20       55
# 16    13              Weedle      Bug  Poison    195   40      35       30
# 17    14              Kakuna      Bug  Poison    205   45      25       50
# 44    39          Jigglypuff   Normal   Fairy    270  115      45       20
# 97    90            Shellder    Water     NaN    305   30      65      100
# 106   98              Krabby    Water     NaN    325   30     105       90
# 125  116              Horsea    Water     NaN    295   30      40       70
# 139  129            Magikarp    Water     NaN    200   20      10       55
# 188  174           Igglybuff   Normal   Fairy    210   90      30       15
# 209  194              Wooper    Water  Ground    210   55      45       45
# ...

# %%
df.loc[df['Sp. Def']<=25].shape
# Out:
# (18, 13)

# %%
(df['Legendary'] == True).sum()
# Out:
# 65

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df['Legendary'].sum()
# Out:
# 65

# %%
df.loc[~df['Legendary'] == False].shape
# Out:
# (735, 13)

# %%
legendary_df = df.loc[df['Legendary']]

legendary_df.head()
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# 157       85      125       90    100           1       True
# 158       90      125       85     90           1       True
# 162       90      154       90    130           1       True
# 163      100      154      100    130           1       True

# %%
ax = sns.scatterplot(data=df, x="Defense", y = "Attack")
ax.annotate(
    "Who's this guy?", xy=(228,10), xytext=(150,10), color='red', arrowprops=dict(arrowstyle="->", color='red')

)

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.sort_values(by=['Defense', 'Attack'], ascending=[False, True]).head()
# Out:
#        #                 Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 230  213              Shuckle    Bug    Rock    505  20      10      230
# 224  208  SteelixMega Steelix  Steel  Ground    610  75     125      230
# 333  306    AggronMega Aggron  Steel     NaN    630  70     140      230
# 223  208              Steelix  Steel  Ground    510  75      85      200
# 414  377             Regirock   Rock     NaN    580  80     100      200
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 230       10      230      5           2      False
# 224       55       95     30           2      False
# 333       60       80     50           3      False
# 223       55       65     30           2      False
# 414       50      100     50           3       True

# %%
df.loc[(df['Type 1'] == 'Fire') & (df['Type 2'] == "Flying")]
# Out:
#        #                       Name Type 1  Type 2  Total   HP  Attack  \
# 6      6                  Charizard   Fire  Flying    534   78      84
# 8      6  CharizardMega Charizard Y   Fire  Flying    634   78     104
# 158  146                    Moltres   Fire  Flying    580   90     100
# 270  250                      Ho-oh   Fire  Flying    680  106     130
# 730  662                Fletchinder   Fire  Flying    382   62      73
# 731  663                 Talonflame   Fire  Flying    499   78      81
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 6         78      109       85    100           1      False
# 8         78      159      115    100           1      False
# 158       90      125       85     90           1       True
# 270       90      110      154     90           2       True
# 730       55       56       52     84           6      False
# 731       71       74       69    126           6      False

# %%
(df['Type 1'] == 'Fire').sum()
# Out:
# 52

# %%
(df['Type 2'] == "Flying").sum()
# Out:
# 97

# %%
(
    (df['Type 1'] == 'Fire') &
    (df['Type 2'] == "Flying")
).sum()
# Out:
# 6

# %%
df.query("`Type 1` == 'Fire' and `Type 2` == 'Flying'")
# Out:
#        #                       Name Type 1  Type 2  Total   HP  Attack  \
# 6      6                  Charizard   Fire  Flying    534   78      84
# 8      6  CharizardMega Charizard Y   Fire  Flying    634   78     104
# 158  146                    Moltres   Fire  Flying    580   90     100
# 270  250                      Ho-oh   Fire  Flying    680  106     130
# 730  662                Fletchinder   Fire  Flying    382   62      73
# 731  663                 Talonflame   Fire  Flying    499   78      81
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 6         78      109       85    100           1      False
# 8         78      159      115    100           1      False
# 158       90      125       85     90           1       True
# 270       90      110      154     90           2       True
# 730       55       56       52     84           6      False
# 731       71       74       69    126           6      False

# %%
df.query("`Type 1` == 'Poison' or `Type 2` == 'Poison'")
# Out:
#        #                   Name  Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur   Grass  Poison    318   45      49       49
# 1      2                Ivysaur   Grass  Poison    405   60      62       63
# 2      3               Venusaur   Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur   Grass  Poison    625   80     100      123
# 16    13                 Weedle     Bug  Poison    195   40      35       30
# ..   ...                    ...     ...     ...    ...  ...     ...      ...
# 630  569               Garbodor  Poison     NaN    474   80      95       82
# 651  590                Foongus   Grass  Poison    294   69      55       45
# 652  591              Amoonguss   Grass  Poison    464  114      85       70
# 760  690                 Skrelp  Poison   Water    320   50      60       60
# 761  691               Dragalge  Poison  Dragon    494   65      75       90
#
# ...

# %%
df.query("`Type 1` == 'Poison' or `Type 2` == 'Poison'").shape
# Out:
# (62, 13)

# %%
 df['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
 df['Type 2'].value_counts()
# Out:
# Type 2
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ghost       14
# Ice         14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.loc[df['Type 1'] == 'Ice'].sort_values(by='Defense', ascending=False)
# Out:
#        #               Name Type 1   Type 2  Total   HP  Attack  Defense  \
# 789  713            Avalugg    Ice      NaN    514   95     117      184
# 522  471            Glaceon    Ice      NaN    525   65      60      110
# 156  144           Articuno    Ice   Flying    580   90      85      100
# 415  378             Regice    Ice      NaN    580   80      50      100
# 400  365            Walrein    Ice    Water    530  110      80       90
# 645  584          Vanilluxe    Ice      NaN    535   71      95       85
# 788  712           Bergmite    Ice      NaN    304   55      69       85
# 524  473          Mamoswine    Ice   Ground    530  110     130       80
# 396  362             Glalie    Ice      NaN    480   80      80       80
# 397  362  GlalieMega Glalie    Ice      NaN    580   80     120       80
# 239  221          Piloswine    Ice   Ground    450  100     100       80
# 675  614            Beartic    Ice      NaN    485   95     110       80
# ...

# %%
df.loc[df['Type 1'] == 'Ice', 'Defense'].max()
# Out:
# 184

# %%
df.loc[df['Legendary'] == True, 'Type 1'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Type 1'>

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.loc[(df["Type 1"] == "Water")].sort_values("Total", ascending=True)
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 381  349                 Feebas  Water     NaN    200   20      15       20
# 139  129               Magikarp  Water     NaN    200   20      10       55
# 209  194                 Wooper  Water  Ground    210   55      45       45
# 293  270                  Lotad  Water   Grass    220   40      30       30
# 198  183                 Marill  Water   Fairy    250   70      20       50
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 283  260  SwampertMega Swampert  Water  Ground    635  100     150      110
# 141  130  GyaradosMega Gyarados  Water    Dark    640   95     155      109
# 421  382                 Kyogre  Water     NaN    670  100     100       90
# 541  484                 Palkia  Water  Dragon    680   90     120      100
# 422  382    KyogrePrimal Kyogre  Water     NaN    770  100     150       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df['Generation'].value_counts(sort=False)
# Out:
# Generation
# 1    166
# 2    106
# 3    160
# 4    121
# 5    165
# 6     82
# Name: count, dtype: int64

# %%
df['Generation'].value_counts(sort=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Generation'>

# %%
df.loc[
    (df["Type 1"] == "Water") &
    (df['Generation'].isin([1,2,3]))].sort_values("Total", ascending=False)
# Out:
#        #                     Name Type 1 Type 2  Total   HP  Attack  Defense  \
# 9      7                 Squirtle  Water    NaN    314   44      48       65
# 10     8                Wartortle  Water    NaN    405   59      63       80
# 11     9                Blastoise  Water    NaN    530   79      83      100
# 12     9  BlastoiseMega Blastoise  Water    NaN    630   79     103      120
# 59    54                  Psyduck  Water    NaN    320   50      52       48
# ..   ...                      ...    ...    ...    ...  ...     ...      ...
# 403  368                 Gorebyss  Water    NaN    485   55      84      105
# 404  369                Relicanth  Water   Rock    485  100      90      130
# 405  370                  Luvdisc  Water    NaN    330   43      30       55
# 421  382                   Kyogre  Water    NaN    670  100     100       90
# 422  382      KyogrePrimal Kyogre  Water    NaN    770  100     150       90
#
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 432 entries, 0 to 431
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           432 non-null    int64
#  1   Name        432 non-null    object
#  2   Type 1      432 non-null    object
#  3   Type 2      215 non-null    object
#  4   Total       432 non-null    int64
#  5   HP          432 non-null    int64
#  6   Attack      432 non-null    int64
#  7   Defense     432 non-null    int64
#  8   Sp. Atk     432 non-null    int64
#  9   Sp. Def     432 non-null    int64
#  10  Speed       432 non-null    int64
#  11  Generation  432 non-null    int64
#  12  Legendary   432 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 44.3+ KB

# %%
df['Generation'].isin([1,2,3]).sum()
# Out:
# 432

# %%
df.query("`Type 1` == 'Dragon' or `Type 2` == 'Dragon'")
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 159  147                    Dratini    Dragon       NaN    300   41      64
# 160  148                  Dragonair    Dragon       NaN    420   61      84
# 161  149                  Dragonite    Dragon    Flying    600   91     134
# 196  181      AmpharosMega Ampharos  Electric    Dragon    610   90      95
# 249  230                    Kingdra     Water    Dragon    540   75      95
# 275  254      SceptileMega Sceptile     Grass    Dragon    630   70     110
# 360  329                    Vibrava    Ground    Dragon    340   50      70
# 361  330                     Flygon    Ground    Dragon    520   80     100
# 365  334                    Altaria    Dragon    Flying    490   75      70
# 366  334        AltariaMega Altaria    Dragon     Fairy    590   75     110
# ...

# %%
df.loc[
    ((df["Type 1"] == 'Dragon') | (df["Type 2"] == 'Dragon')) &
     (df["Generation"].isin([1,2]))
     ].sort_values('Total', ascending=False)
# Out:
#        #                       Name    Type 1  Type 2  Total  HP  Attack  \
# 7      6  CharizardMega Charizard X      Fire  Dragon    634  78     130
# 196  181      AmpharosMega Ampharos  Electric  Dragon    610  90      95
# 161  149                  Dragonite    Dragon  Flying    600  91     134
# 249  230                    Kingdra     Water  Dragon    540  75      95
# 160  148                  Dragonair    Dragon     NaN    420  61      84
# 159  147                    Dratini    Dragon     NaN    300  41      64
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 7        111      130       85    100           1      False
# 196      105      165      110     45           2      False
# 161       95      100      100     80           1      False
# 249       95       95       95     85           2      False
# 160       65       70       70     70           1      False
# 159       45       50       50     50           1      False

# %%
df['Generation'].value_counts(sort=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Generation'>

# %%
df.loc[
    ((df["Type 1"] == 'Dragon') | 
    (df["Type 2"] == 'Dragon')) &
    (df["Generation"].isin({5,6}))].sort_values('Total', ascending=False)
# Out:
#        #                Name  Type 1    Type 2  Total   HP  Attack  Defense  \
# 711  646  KyuremBlack Kyurem  Dragon       Ice    700  125     170      100
# 712  646  KyuremWhite Kyurem  Dragon       Ice    700  125     120       90
# 706  643            Reshiram  Dragon      Fire    680  100     120      100
# 707  644              Zekrom  Dragon  Electric    680  100     150      120
# 710  646              Kyurem  Dragon       Ice    660  125     130       90
# 776  706              Goodra  Dragon       NaN    600   90     100       70
# 794  718    Zygarde50% Forme  Dragon    Ground    600  108     100      121
# 696  635           Hydreigon    Dark    Dragon    600   92     105       90
# 673  612             Haxorus  Dragon       NaN    540   76     147       90
# 791  715             Noivern  Flying    Dragon    535   85      70       80
# 767  697           Tyrantrum    Rock    Dragon    521   82     121      119
# ...

# %%
df.loc[
    (df['Type 1'] == 'Fire') &
    (df['Attack'] > 100)
]
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 147  136                    Flareon   Fire       NaN    525   65     130
# 263  244                      Entei   Fire       NaN    580  115     115
# 270  250                      Ho-oh   Fire    Flying    680  106     130
# 278  257                   Blaziken   Fire  Fighting    530   80     120
# 279  257      BlazikenMega Blaziken   Fire  Fighting    630   80     160
# 354  323      CameruptMega Camerupt   Fire    Ground    560   70     120
# 437  392                  Infernape   Fire  Fighting    534   76     104
# 559  500                     Emboar   Fire  Fighting    528  110     123
# 615  555    DarmanitanStandard Mode   Fire       NaN    480  105     140
# ...

# %%
df.query("`Type 1` == 'Fire' and `Attack` > 100")
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 147  136                    Flareon   Fire       NaN    525   65     130
# 263  244                      Entei   Fire       NaN    580  115     115
# 270  250                      Ho-oh   Fire    Flying    680  106     130
# 278  257                   Blaziken   Fire  Fighting    530   80     120
# 279  257      BlazikenMega Blaziken   Fire  Fighting    630   80     160
# 354  323      CameruptMega Camerupt   Fire    Ground    560   70     120
# 437  392                  Infernape   Fire  Fighting    534   76     104
# 559  500                     Emboar   Fire  Fighting    528  110     123
# 615  555    DarmanitanStandard Mode   Fire       NaN    480  105     140
# ...

# %%
water_flying_of = df.loc[(df['Type 1'] == 'Water') & (df['Type 2'] == 'Flying')]

# %%
water_flying_of
# Out:
#        #      Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 140  130  Gyarados  Water  Flying    540  95     125       79       60
# 244  226   Mantine  Water  Flying    465  65      40       70       80
# 301  278   Wingull  Water  Flying    270  40      30       30       55
# 302  279  Pelipper  Water  Flying    430  60      50      100       85
# 508  458   Mantyke  Water  Flying    345  45      20       50       60
# 641  580  Ducklett  Water  Flying    305  62      44       50       44
# 642  581    Swanna  Water  Flying    473  75      87       63       87
#
#      Sp. Def  Speed  Generation  Legendary
# 140      100     81           1      False
# 244      140     70           2      False
# 301       30     85           3      False
# 302       70     65           3      False
# 508      120     50           4      False
# 641       50     55           5      False
# 642       63     98           5      False

# %%
legendary_fire_df = df.loc[
    ((df["Legendary"] == True) & (df['Type 1'] == 'Fire')), 
    (['Name', 'Attack', 'Generation'])
]
legendary_fire_df
# Out:
#           Name  Attack  Generation
# 158    Moltres     100           1
# 263      Entei     115           2
# 270      Ho-oh     130           2
# 542    Heatran      90           4
# 799  Volcanion     110           6

# %%
df.loc[
    CONDITIONS FORINDEX,
    (COLUMNS)
]

# %%
ax = df['Speed'].plot(kind='hist', figsize=(10,5), bins=10)
ax.axvline(df['Speed'].quantile(.05), color='red')
ax.axvline(df['Speed'].quantile(.95), color='red')

# %%
bottom_five = df['Speed'].quantile(.05)
top_five = df['Speed'].quantile(.95)
(bottom_five, top_five)
# slow_fast_df = df.
# Out:
# (25.0, 115.0)

# %%
slow_fast_df = df.loc[
    (df['Speed'] < bottom_five) |
    (df['Speed'] > top_five)
]

# %%
slow_fast_df
# Out:
#        #                   Name    Type 1  Type 2  Total   HP  Attack  \
# 19    15  BeedrillMega Beedrill       Bug  Poison    495   65     150
# 23    18    PidgeotMega Pidgeot    Normal  Flying    579   83      80
# 44    39             Jigglypuff    Normal   Fairy    270  115      45
# 56    51                Dugtrio    Ground     NaN    405   35      80
# 70    65               Alakazam   Psychic     NaN    500   55      50
# ..   ...                    ...       ...     ...    ...  ...     ...
# 726  658               Greninja     Water    Dark    530   72      95
# 731  663             Talonflame      Fire  Flying    499   78      81
# 752  682               Spritzee     Fairy     NaN    341   78      52
# 771  701               Hawlucha  Fighting  Flying    500   78      92
# 791  715                Noivern    Flying  Dragon    535   85      70
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 19        40       15       80    145           1      False
# ...

# %%
fig, ax = plt.subplots(figsize=(14,7))
sns.scatterplot(data=df, x='Defense', y="Attack", hue='Legendary', ax=ax)
# Out:
# <Axes: xlabel='Defense', ylabel='Attack'>

# %%
df.loc[df['Legendary']].sort_values(by=['Attack', 'Defense'], ascending=False)
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 429  386     DeoxysAttack Forme  Psychic       NaN    600   50     180
# 711  646     KyuremBlack Kyurem   Dragon       Ice    700  125     170
# ..   ...                    ...      ...       ...    ...  ...     ...
# 416  379              Registeel    Steel       NaN    580   80      75
# 537  480                   Uxie  Psychic       NaN    580   75      75
# 264  245                Suicune    Water       NaN    580  100      75
# 430  386    DeoxysDefense Forme  Psychic       NaN    600   50      70
# 415  378                 Regice      Ice       NaN    580   80      50
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...
